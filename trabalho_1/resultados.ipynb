# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Desktop

# %%
bubble_sort = {
    '10k': {
        'Tempo Gasto': '0:03:19.255147',
        'Pico de memória (MB)': 0.00031,
        'Comparações': 99410058,
        'Trocas': 25297553,
        'Passadas': 9942
    },
    '20k': {
        'Tempo Gasto': '0:20:54.944999',
        'Pico de memória (MB)': 0.00031,
        'Comparações': 616850325,
        'Trocas': 157485392,
        'Passadas': 24675
    },
    '50k': {
        'Tempo Gasto': '1:24:46.323227',
        'Pico de memória (MB)': 0.00032,
        'Comparações': 2467600647,
        'Trocas': 625828205,
        'Passadas': 49353
    },
    '100k': {
        'Tempo Gasto': '5:40:07.089815',
        'Pico de memória (MB)': 0.00032,
        'Comparações': 9925800741,
        'Trocas': 2498177562,
        'Passadas': 99259
    }
}

selection_sort = {
    '10k': {
        'Tempo Gasto': '0:00:57.590540',
        'Pico de memória (MB)': 0.0004,
        'Comparações': 49995000,
        'Trocas': 9990,
        'Passadas': 9999
    },
    '25k': {
        'Tempo Gasto': '0:06:05.828327',
        'Pico de memória (MB)': 0.0004,
        'Comparações': 312487500,
        'Trocas': 24984,
        'Passadas': 24999
    },
    '50k': {
        'Tempo Gasto': '0:25:05.384494',
        'Pico de memória (MB)': 0.0004,
        'Comparações': 1249975000,
        'Trocas': 49991,
        'Passadas': 49999
    },
    '100k': {
        'Tempo Gasto': '1:42:56.398500',
        'Pico de memória (MB)': 0.0004,
        'Comparações': 4999950000,
        'Trocas': 99982,
        'Passadas': 99999
    }
}

merge_sort = {
    '10k': {
        'Tempo Gasto': '0:00:00.315189',
        'Pico de memória (MB)': 0.23533,
        'Divisões': 9999,
        'Junções': 9999,
        'Comparações': 120188
    },
    '25k': {
        'Tempo Gasto': '0:00:00.790905',
        'Pico de memória (MB)': 0.59077,
        'Divisões': 24999,
        'Junções': 24999,
        'Comparações': 333562
    },
    '50k': {
        'Tempo Gasto': '0:00:01.730634',
        'Pico de memória (MB)': 1.18712,
        'Divisões': 49999,
        'Junções': 49999,
        'Comparações': 716989
    },
    '100k': {
        'Tempo Gasto': '0:00:03.787339',
        'Pico de memória (MB)': 2.29016,
        'Divisões': 99999,
        'Junções': 99999,
        'Comparações': 1534073
    }
}

merge_sort_iter = {
    '10k': {
        'Tempo Gasto': '0:00:00.696944',
        'Pico de memória (MB)': 0.0836,
        'Divisões': 10005,
        'Junções': 10005,
        'Comparações': 133931
    },
    '25k': {
        'Tempo Gasto': '0:00:01.902887',
        'Pico de memória (MB)': 0.22401,
        'Divisões': 25006,
        'Junções': 25006,
        'Comparações': 362203
    },
    '50k': {
        'Tempo Gasto': '0:00:03.977243',
        'Pico de memória (MB)': 0.44761,
        'Divisões': 50006,
        'Junções': 50006,
        'Comparações': 773356
    },
    '100k': {
        'Tempo Gasto': '0:00:08.634972',
        'Pico de memória (MB)': 0.89482,
        'Divisões': 100006,
        'Junções': 100006,
        'Comparações': 1648605
    }
}

quick_sort = {
    '10k': {
        'Tempo Gasto': '0:00:00.401638',
        'Pico de memória (MB)': 0.00376,
        'Comparações': 247491,
        'Trocas': 74724,
        'Passadas': 6739
    },
    '25k': {
        'Tempo Gasto': '0:00:00.993392',
        'Pico de memória (MB)': 0.00559,
        'Comparações': 616240,
        'Trocas': 183025,
        'Passadas': 16815
    },
    '50k': {
        'Tempo Gasto': '0:00:02.480724',
        'Pico de memória (MB)': 0.01694,
        'Comparações': 1435726,
        'Trocas': 442266,
        'Passadas': 33606
    },
    '100k': {
        'Tempo Gasto': '0:00:05.054936',
        'Pico de memória (MB)': 0.0174,
        'Comparações': 3148139,
        'Trocas': 924104,
        'Passadas': 67259
    }
}

quick_sort_iter = {
    '10k': {
        'Tempo Gasto': '0:00:00.512516',
        'Pico de memória (MB)': 0.07767,
        'Comparações': 159494,
        'Trocas': 88396,
        'Passadas': 6709
    },
    '25k': {
        'Tempo Gasto': '0:00:01.272187',
        'Pico de memória (MB)': 0.19224,
        'Comparações': 402578,
        'Trocas': 216674,
        'Passadas': 16848
    },
    '50k': {
        'Tempo Gasto': '0:00:02.927801',
        'Pico de memória (MB)': 0.38297,
        'Comparações': 929208,
        'Trocas': 520436,
        'Passadas': 33596
    },
    '100k': {
        'Tempo Gasto': '0:00:06.394516',
        'Pico de memória (MB)': 0.76469,
        'Comparações': 2103882,
        'Trocas': 1081151,
        'Passadas': 67185
    }
}

# %%
data = [bubble_sort['10k'], selection_sort['10k'], merge_sort['10k'], merge_sort_iter['10k'], quick_sort['10k'], quick_sort_iter['10k']]
index = ['Bubble Sort', 'Selection Sort', 'Merge Sort', 'Merge Sort Iter', 'Quick Sort', 'Quick Sort Iter']
df = pd.DataFrame(data, index=index)
df['Tempo Gasto'] = pd.to_timedelta(df['Tempo Gasto'])
# df['Tempo (segundos)'] = df['Tempo Gasto'].dt.total_seconds()
df
# Out:
#                            Tempo Gasto  Pico de memória (MB)  Comparações  \
# Bubble Sort     0 days 00:03:19.255147               0.00031     99410058
# Selection Sort  0 days 00:00:57.590540               0.00040     49995000
# Merge Sort      0 days 00:00:00.315189               0.23533       120188
# Merge Sort Iter 0 days 00:00:00.696944               0.08360       133931
# Quick Sort      0 days 00:00:00.401638               0.00376       247491
# Quick Sort Iter 0 days 00:00:00.512516               0.07767       159494
#
#                      Trocas  Passadas  Divisões  Junções
# Bubble Sort      25297553.0    9942.0       NaN      NaN
# Selection Sort       9990.0    9999.0       NaN      NaN
# Merge Sort              NaN       NaN    9999.0   9999.0
# Merge Sort Iter         NaN       NaN   10005.0  10005.0
# Quick Sort          74724.0    6739.0       NaN      NaN
# Quick Sort Iter     88396.0    6709.0       NaN      NaN

# %%
df.loc['Bubble Sort']
# Out:
# Tempo Gasto             0 days 00:01:43.652536
# Pico de memória (MB)                   0.00029
# Comparações                           99410058
# Trocas                              25297553.0
# Passadas                                9942.0
# Divisões                                   NaN
# Junções                                    NaN
# Tempo gasto                                NaN
# Pico de memória                            NaN
# Name: Bubble Sort, dtype: object

# %%
media_tempo = pd.TimedeltaIndex(df['Tempo Gasto']).mean()
media_tempo
# Out:
# Timedelta('0 days 00:00:43.128662333')

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(y=df.index, x=df['Tempo Gasto'].dt.total_seconds())
plt.title('Tempo Gasto por Algoritmo')
# plt.ylabel('Tempo (s)')
plt.ylabel('Algoritmo')
plt.show()

# %% [markdown]
# #### Notebook

# %%
bubble_sort = {
    '10k': {
        'Tempo Gasto': '0:01:43.652536',
        'Pico de memória (MB)': 0.00029,
        'Comparações': 99410058,
        'Trocas': 25297553,
        'Passadas': 9942
    },
    '25k': {
        'Tempo Gasto': '0:11:22.774309',
        'Pico de memória (MB)': 0.00029,
        'Comparações': 616850325,
        'Trocas': 157485392,
        'Passadas': 24675
    },
    '50k': {
        'Tempo Gasto': '0:45:45.062958',
        'Pico de memória (MB)': 0.0003,
        'Comparações': 2467600647,
        'Trocas': 625828205,
        'Passadas': 49353
    },
    '100k': {
        'Tempo Gasto': '3:08:49.366995',
        'Pico de memória (MB)': 0.00031,
        'Comparações': 9925800741,
        'Trocas': 2498177562,
        'Passadas': 99259
    }
}

selection_sort = {
    '10k': {
        'Tempo Gasto': '0:00:30.066958',
        'Pico de memória (MB)': 0.00042,
        'Comparações': 49995000,
        'Trocas': 9990,
        'Passadas': 9999
    },
    '25k': {
        'Tempo Gasto': '0:03:10.794170',
        'Pico de memória (MB)': 0.00042,
        'Comparações': 312487500,
        'Trocas': 24984,
        'Passadas': 24999
    },
    '50k': {
        'Tempo Gasto': '0:13:11.570059',
        'Pico de memória (MB)': 0.00042,
        'Comparações': 1249975000,
        'Trocas': 49991,
        'Passadas': 49999
    },
    '100k': {
        'Tempo Gasto': '0:53:38.657204',
        'Pico de memória (MB)': 0.00042,
        'Comparações': 4999950000,
        'Trocas': 99982,
        'Passadas': 99999
    }
}

merge_sort = {
    '10k': {
        'Tempo Gasto': '0:00:00.169351',
        'Pico de memória (MB)': 0.24185,
        'Divisões': 9999,
        'Junções': 9999,
        'Comparações': 120188
    },
    '25k': {
        'Tempo Gasto': '0:00:00.463508',
        'Pico de memória (MB)': 0.5916,
        'Divisões': 24999,
        'Junções': 24999,
        'Comparações': 333562
    },
    '50k': {
        'Tempo Gasto': '0:00:01.018003',
        'Pico de memória (MB)': 1.18794,
        'Divisões': 49999,
        'Junções': 49999,
        'Comparações': 716989
    },
    '100k': {
        'Tempo Gasto': '0:00:02.219619',
        'Pico de memória (MB)': 2.29099,
        'Divisões': 99999,
        'Junções': 99999,
        'Comparações': 1534073
    }
}

merge_sort_iter = {
    '10k': {
        'Tempo Gasto': '0:00:00.284596',
        'Pico de memória (MB)': 0.08356,
        'Divisões': 10005,
        'Junções': 10005,
        'Comparações': 133931
    },
    '25k': {
        'Tempo Gasto': '0:00:00.780980',
        'Pico de memória (MB)': 0.22397,
        'Divisões': 25006,
        'Junções': 25006,
        'Comparações': 362203
    },
    '50k': {
        'Tempo Gasto': '0:00:01.666968',
        'Pico de memória (MB)': 0.44757,
        'Divisões': 50006,
        'Junções': 50006,
        'Comparações': 773356
    },
    '100k': {
        'Tempo Gasto': '0:00:03.663735',
        'Pico de memória (MB)': 0.89478,
        'Divisões': 100006,
        'Junções': 100006,
        'Comparações': 1648605
    }
}

quick_sort = {
    '10k': {
        'Tempo Gasto': '0:00:00.236792',
        'Pico de memória (MB)': '0.02096',
        'Comparações': 247491,
        'Trocas': 74724,
        'Passadas': 6739
    },
    '25k': {
        'Tempo Gasto': '0:00:00.609582',
        'Pico de memória (MB)': '0.01416',
        'Comparações': 616240,
        'Trocas': 183025,
        'Passadas': 16815
    },
    '50k': {
        'Tempo Gasto': '0:00:01.427936',
        'Pico de memória (MB)': '0.07012',
        'Comparações': 1435726,
        'Trocas': 442266,
        'Passadas': 33606
    },
    '100k': {
        'Tempo Gasto': '0:00:03.250276',
        'Pico de memória (MB)': '0.01786',
        'Comparações': 3148139,
        'Trocas': 924104,
        'Passadas': 67259
    }
}

quick_sort_iter = {
    '10k': {
        'Tempo Gasto': '0:00:00.188127',
        'Pico de memória (MB)': 0.07752,
        'Comparações': 159494,
        'Trocas': 88396,
        'Passadas': 6709
    },
    '25k': {
        'Tempo Gasto': '0:00:00.476993',
        'Pico de memória (MB)': 0.19207,
        'Comparações': 402578,
        'Trocas': 216674,
        'Passadas': 16848
    },
    '50k': {
        'Tempo Gasto': '0:00:01.103665',
        'Pico de memória (MB)': 0.3828,
        'Comparações': 929208,
        'Trocas': 520436,
        'Passadas': 33596
    },
    '100k': {
        'Tempo Gasto': '0:00:02.448788',
        'Pico de memória (MB)': 0.76448,
        'Comparações': 2103882,
        'Trocas': 1081151,
        'Passadas': 67185
    }
}

# %%
# Criação do dataframe para bubble_sort
df_bubble = pd.DataFrame.from_dict(bubble_sort, orient='index')
df_bubble.index.name = 'Tamanho'
df_bubble.columns.name = 'Estatísticas Bubble Sort'

# Criação do dataframe para selection_sort
df_selection = pd.DataFrame.from_dict(selection_sort, orient='index')
df_selection.index.name = 'Tamanho'
df_selection.columns.name = 'Estatísticas Selection Sort'

# Concatenação dos dois dataframes
df = pd.concat([df_bubble, df_selection], axis=1)
df
# Out:
#             Tempo Gasto  Pico de memória (MB)  Comparações      Trocas  \
# Tamanho
# 10k      0:01:43.652536               0.00029     99410058    25297553
# 25k      0:11:22.774309               0.00029    616850325   157485392
# 50k      0:45:45.062958               0.00030   2467600647   625828205
# 100k     3:08:49.366995               0.00031   9925800741  2498177562
#
#          Passadas     Tempo Gasto  Pico de memória (MB)  Comparações  Trocas  \
# Tamanho
# 10k          9942  0:00:30.066958               0.00042     49995000    9990
# 25k         24675  0:03:10.794170               0.00042    312487500   24984
# 50k         49353  0:13:11.570059               0.00042   1249975000   49991
# 100k        99259  0:53:38.657204               0.00042   4999950000   99982
#
#          Passadas
# Tamanho
# 10k          9999
# 25k         24999
# 50k         49999
# 100k        99999

# %%
tamanhos = ['10k', '25k', '50k', '100k']
df = pd.DataFrame(columns=['Tempo Gasto', 'Pico de memória (MB)', 'Comparações', 'Trocas', 'Passadas', 'Divisões', 'Junções', 'Algoritmo', 'Tamanho'])

for tamanho in tamanhos:

    data = [bubble_sort[tamanho], selection_sort[tamanho], merge_sort[tamanho], merge_sort_iter[tamanho], quick_sort[tamanho], quick_sort_iter[tamanho]]
    algoritmos = ['Bubble Sort', 'Selection Sort', 'Merge Sort', 'Merge Sort Iter', 'Quick Sort', 'Quick Sort Iter']
    df_temp = pd.DataFrame(data)
    df_temp['Tempo Gasto'] = pd.to_timedelta(df_temp['Tempo Gasto'])
    df_temp['Algoritmo'] = algoritmos
    df_temp['Tamanho'] = tamanho
    # df_temp['Tempo (segundos)'] = df_temp['Tempo Gasto'].dt.total_seconds()
    
    df = pd.concat([df, df_temp])

df
# Out:
#              Tempo Gasto Pico de memória (MB) Comparações        Trocas  \
# 0 0 days 00:01:43.652536              0.00029    99410058  2.529755e+07
# 1 0 days 00:00:30.066958              0.00042    49995000  9.990000e+03
# 2 0 days 00:00:00.169351              0.24185      120188           NaN
# 3 0 days 00:00:00.284596              0.08356      133931           NaN
# 4 0 days 00:00:00.236792              0.02096      247491  7.472400e+04
# 5 0 days 00:00:00.188127              0.07752      159494  8.839600e+04
# 0 0 days 00:11:22.774309              0.00029   616850325  1.574854e+08
# 1 0 days 00:03:10.794170              0.00042   312487500  2.498400e+04
# 2 0 days 00:00:00.463508               0.5916      333562           NaN
# 3 0 days 00:00:00.780980              0.22397      362203           NaN
# 4 0 days 00:00:00.609582              0.01416      616240  1.830250e+05
# 5 0 days 00:00:00.476993              0.19207      402578  2.166740e+05
# ...

# %%
plt.style.use('seaborn')
sns.displot(x='Algoritmo', col='Pico de memória (MB)', hue='Algoritmo', kde=True, data=df).set(ylabel='Frequência')
# Out:
# C:\Users\joaoteixeira\AppData\Local\Temp\ipykernel_8316\4112777499.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
